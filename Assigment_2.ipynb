# %% [markdown]
# ### __Note:__
# #### I got network error when I tried to import house data from sklearn.datasets.fetch_california_housing so I downloaded it from Kaggle

# %%
file_name='housing.csv'

# %%
import pandas as pd
import numpy as np

# %%
housing=pd.read_csv(file_name)

# %%
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housing.shape
# Out:
# (20640, 10)

# %%
housing.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
housing.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# #### There is (20640 - 20433 =207 ) 207 null values in total_bedrooms column

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# #### variance of each features

# %%
housing.describe().loc['std']
# Out:
# longitude                  2.003532
# latitude                   2.135952
# housing_median_age        12.585558
# total_rooms             2181.615252
# total_bedrooms           421.385070
# population              1132.462122
# households               382.329753
# median_income              1.899822
# median_house_value    115395.615874
# Name: std, dtype: float64

# %% [markdown]
# ###

# %% [markdown]
# ## Univariate Analysis (Histograms)

# %%
import matplotlib.pyplot as plt

# %%
fig,ax=plt.subplots(3,3,figsize=(14,11))
fig.subplots_adjust(hspace=0.5, wspace=1)

# %%
#  lognitude at (0,0)
ax[0][0].hist(housing['longitude'],edgecolor='black',color='#ADD8E6',bins=30)
ax[0][0].set_xlabel('longitude',color='#8B0000',fontsize=10)
ax[0][0].set_ylabel('frequency',color='#8B0000',fontsize=10)
ax[0][0].set_title('Longitude Distribution',color='#8B0000',fontsize=12)

#  latitude at (0,0)
ax[0][1].hist(housing['latitude'],edgecolor='black',color='#ADD8E6',bins=30)
ax[0][1].set_xlabel('latitude',color='#8B0000',fontsize=10)
ax[0][1].set_ylabel('frequency',color='#8B0000',fontsize=10)
ax[0][1].set_title('latitude Distribution',color='#8B0000',fontsize=12)

#  housing_median_age at (0,0)
ax[0][2].hist(housing['housing_median_age'],edgecolor='black',color='#ADD8E6',bins=30)
ax[0][2].set_xlabel('housing_median_age',color='#8B0000',fontsize=10)
ax[0][2].set_ylabel('frequency',color='#8B0000',fontsize=10)
ax[0][2].set_title('Housing Median Age Distribution',color='#8B0000',fontsize=12)

#  total rooms	 at (0,0)
ax[1][0].hist(housing['total_rooms'],edgecolor='black',color='#ADD8E6',bins=30)
ax[1][0].set_xlabel('total_rooms',color='#8B0000',fontsize=10)
ax[1][0].set_ylabel('frequency',color='#8B0000',fontsize=10)
ax[1][0].set_title('Total Rooms Distribution',color='#8B0000',fontsize=12)

#  total bedrooms at (0,0)
ax[1][1].hist(housing['total_bedrooms'],edgecolor='black',color='#ADD8E6',bins=30)
ax[1][1].set_xlabel('total bedrooms',color='#8B0000',fontsize=10)
ax[1][1].set_ylabel('frequency',color='#8B0000',fontsize=10)
ax[1][1].set_title('Total Bedrooms Distribution',color='#8B0000',fontsize=12)

#  population at (0,0)
ax[1][2].hist(housing['population'],edgecolor='black',color='#ADD8E6',bins=30)
ax[1][2].set_xlabel('population',color='#8B0000',fontsize=10)
ax[1][2].set_ylabel('frequency',color='#8B0000',fontsize=10)
ax[1][2].set_title('Population Distribution',color='#8B0000',fontsize=12)

#  households	 at (0,0)
ax[2][0].hist(housing['households'],edgecolor='black',color='#ADD8E6',bins=30)
ax[2][0].set_xlabel('households',color='#8B0000',fontsize=10)
ax[2][0].set_ylabel('frequency',color='#8B0000',fontsize=10)
ax[2][0].set_title('Households Distribution',color='#8B0000',fontsize=12)

#  median_income at (0,0)
ax[2][1].hist(housing['median_income'],edgecolor='black',color='#ADD8E6',bins=30)
ax[2][1].set_xlabel('median income',color='#8B0000',fontsize=10)
ax[2][1].set_ylabel('frequency',color='#8B0000',fontsize=10)
ax[2][1].set_title('Median Income Distribution',color='#8B0000',fontsize=12)

#  median_house_value at (0,0)
ax[2][2].hist(housing['median_house_value'],edgecolor='black',color='#ADD8E6',bins=30)
ax[2][2].set_xlabel('median_house_value',color='#8B0000',fontsize=10)
ax[2][2].set_ylabel('frequency',color='#8B0000',fontsize=10)
ax[2][2].set_title('Median House Value Distribution',color='#8B0000',fontsize=12)
fig

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].boxplot(housing['median_income'])
ax[0].set_title("Median Income(in tens of $1000)")

ax[1].boxplot(housing['total_rooms'])
ax[1].set_title("Total Rooms")

ax[2].boxplot(housing['population'])
ax[2].set_title("Population")
# Out:
# Text(0.5, 1.0, 'Population')

# %% [markdown]
# #### For median income, the middle 50% of census blocks lie roughly between 2k to 4.5K dollars, while blocks with median income above approximately $8K fall outside the whiskers and appear as outliers.
# #### In the case of total rooms, most blocks are concentrated between about 1,000 and 4,000 rooms, with values above roughly 7,000 rooms appearing as outliers.
# #### Similarly, population is mainly concentrated between about 1,000 and 2,000 people, while blocks with populations above approximately 3.5k - 4K appear as outliers

# %% [markdown]
# ###

# %% [markdown]
# ### *__Explain most widely used methods to eliminate skewness of column features__*

# %% [markdown]
# #### __1. Log Transformation:__ It shrinks very large numbers much more than small ones, which helps pull a long "tail" back toward the center.
# #### __2. Square Root Transformation:__ It is a "gentle" fix that pulls large numbers in slightly, making it perfect for data that isn't too badly skewed.
# #### __3. Box-Cox Transformation:__ It tests different math powers to find the perfect one that makes our data look like a balanced bell curve.
# #### __4. Yeo-Johnson Transformation:__ It works exactly like Box-Cox but working even if our data has zeros or negative numbers.
# #### __5. Reciprocal Transformation:__ It turns every number into a fraction ($1$ divided by the number), which completely flips the data to make huge values very tiny.

# %% [markdown]
# ##

# %% [markdown]
# ### Correlation Heatmap

# %%
# find correlation matrix
cm = housing.corr(numeric_only=True)

# %%
#plot heatmap using seaborn 
import seaborn as sns
sns.heatmap(cm, cmap="crest",vmin= -1, vmax= +1,annot=True, linewidth=.1,linecolor='#ADD8E6')
# Out:
# <Axes: >

# %% [markdown]
# #### we can see that  __longitude__ and __latitude__  have not a good corelation with any of the other features while __median income__ has strong __0.69__ positive correlation with __house price__
# #### __housing age__ has weak negative correlation with total rooms, bedrooms, population and households

# %% [markdown]
# ##

# %% [markdown]
# ## Latitude/Longitude Visualization

# %% [markdown]
# #### first convert MedHouseVal and Population in range of 0 to 1

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
mhv_scaled = scaler.fit_transform(housing['median_house_value'].to_numpy().reshape(-1, 1))

population_scaled=scaler.fit_transform(housing['population'].to_numpy().reshape(-1, 1))

# %%
fig,ax=plt.subplots(1, 1)

size=housing['population']
sc = ax.scatter(housing['longitude'],
                housing['latitude'], 
                c=mhv_scaled, 
                cmap='winter',
                s=population_scaled*200,
                edgecolors='white',
                linewidths=0.2)
ax.set_xlabel('Longitude',color='#8B0000')
ax.set_ylabel('Latitude',color='#8B0000')
ax.set_title('size of points is based on population',color='#8B0000')

#ax.colorbar() -->this will give error " 'Axes' object has no attribute 'colorbar' "
plt.colorbar(sc,ax=ax, label='Median House Value')

# %% [markdown]
# #### we can see that at [latitude 37 to 38 and longitude -123 to -124] and [latitude around 34 and longitude -119 to -118] house value are high

# %% [markdown]
# ###

# %% [markdown]
# ### *__why scaling is required before PCA__*

# %% [markdown]
# #### Scaling is necessary because PCA identifies patterns by maximizing variance, making it highly sensitive to the raw numerical range of the data. For example, in a dataset containing Age (0–100) and Income (0–100k), a variance of 50 in Age is significant (covering half the range), whereas a variance of 50 in Income is negligible. Without scaling, PCA would mathematically perceive Income as more "important" simply because its numbers are larger, allowing it to dominate the principal components and lead to a biased result.
# #### By scaling the data to a 0 mean and 1 standard deviation, we normalize the features so they contribute equally, ensuring the PCA results reflect the true relationships in the data regardless of the original units

# %%
# PCA on feature
from sklearn.preprocessing import StandardScaler # importing library to perform center and scaling
sc = StandardScaler()

dataset = housing.drop(['median_house_value','ocean_proximity'],axis=1)  # drop target value(house value) and string value(ocean proximity)
dataset.fillna(dataset['total_bedrooms'].mean(),inplace=True)  # drop the row with NAN value
data = sc.fit_transform(dataset)

# apply PCA
from sklearn.decomposition import PCA
pca = PCA()
pca.fit_transform(data)
# Out:
# array([[-2.09440215,  1.39547053,  2.04939231, ..., -0.14750612,
#         -0.22990773, -0.09290297],
#        [ 2.94343933,  1.9333788 ,  2.15093428, ..., -0.06508193,
#          0.06484734,  0.26025687],
#        [-1.97072079,  1.46420722,  1.17989241, ...,  0.03891408,
#         -0.08720793, -0.0686732 ],
#        ...,
#        [-0.44918446,  1.80976506, -0.52526584, ...,  0.36807399,
#         -0.28655188,  0.07740755],
#        [-0.86152372,  1.79815858, -0.41943833, ...,  0.34547417,
#         -0.26762737,  0.053603  ],
#        [ 0.13998265,  1.84530728, -0.25177594, ...,  0.32659814,
#         -0.34697034,  0.00633345]], shape=(20640, 8))

# %%
explained_variance = (pca.explained_variance_ratio_)*100  # convert explained variance to perrcentage
explained_variance
# Out:
# array([48.76068377, 23.84710229, 13.39799393, 10.27549435,  1.87075645,
#         1.01839403,  0.58773886,  0.24183632])

# %%
# plot PCA vs variance they explained plot

# PCA labels
pca_labels = [f'PCA{i}' for i in range(1, 9)]

# Create plot
plt.figure(figsize=(8, 5))
plt.bar( pca_labels, explained_variance, color='#ADD8E6',edgecolor='black')

# Labels and title
plt.xlabel('Principal Components', color='#8B0000', fontsize=11)
plt.ylabel('Explained Variance (%)', color='#8B0000', fontsize=11)
plt.title('PCAs vs Variance They Explained', color='#8B0000', fontsize=13)

# Tick color
plt.xticks(color='#8B0000')
plt.yticks(color='#8B0000')

# annotate values on bars
for i, val in enumerate(explained_variance):
    plt.text(i, val+1, f'{val:.2f}%' , horizontalalignment='center',verticalalignment='center', color='#8B0000')
    # first two arguments coordinates i.e tex at (i, val+1)
    # third argument is text
    #all other are text properties

plt.tight_layout()
plt.show()

# %% [markdown]
# ####  Scatter plot:PC1 vs PC2

# %%
pca_2 = PCA(n_components=2) # n_components=2 -->give first two PCA which is PCA1 and PCA2
data_pca_2=pca_2.fit_transform(data) 
data_pca_2 # first column is PCA1 values for all 20433 data points and second column is PCA2
# Out:
# array([[-2.09440215,  1.39547053],
#        [ 2.94343933,  1.9333788 ],
#        [-1.97072079,  1.46420722],
#        ...,
#        [-0.44918446,  1.80976506],
#        [-0.86152372,  1.79815858],
#        [ 0.13998265,  1.84530728]], shape=(20640, 2))

# %%
data_pca_2[:,0].max() # 32.2
# Out:
# np.float64(32.201991798667834)

# %%
data_pca_2[:,1].max()  # 4.76
# Out:
# np.float64(4.761851728152302)

# %%
plt.scatter(data_pca_2[:,0], data_pca_2[:,1], c=mhv_scaled,cmap='winter',edgecolor='white',linewidths=0.2,s=15)
plt.xlabel('PCA 1 (48.76%)',color='#8B0000', fontsize=11)
plt.ylabel('PCA 2 (23.85%)',color='#8B0000', fontsize=11)
plt.title('PCA 1 vs PCA 2',color='#8B0000')

plt.colorbar(label='Median House Value')

# %% [markdown]
# #### As PCA 1 increases, the points change from blue to green, which means house prices increase with PCA 1. This shows that PCA 1 captures most of the variation related to house prices. Along the PCA 2 direction, there is no clear change in color, which means PCA 2 represents secondary variation that is not directly related to house prices and includes information not explained by PCA 1.
#
# #### PCA 1 has a much larger spread than PCA 2, so it explains most of the variation in the dataset. The data does not form clear clusters and instead changes smoothly, which suggests that regression models are more suitable than classification models. The spread of data along PCA 1 also shows that changes in features do not affect all house prices in the same way and can have different effects in different parts of the dataset

# %% [markdown]
# ####

# %% [markdown]
# ## Implement multiple linear regression

# %%
class multi_linear_reg:
    def __init__(self,learning_rate=0.01,max_iteration=1000):
        self.lr=learning_rate 
        self.a=None # weight
        # take n+1 perameter into weigth last one  is for bias
        
        self.max_iteration=max_iteration
        print('learning rate(lr)=',self.lr,'\nmaximum iteration=', self.max_iteration)
     
    def loss(self,x,y):
        # assume initial line as y=[0]*x + [0]
        loss_fun= ( y - x@self.a )**2
        return np.sum(loss_fun)/(2*len(y))  # no of data points is same as len of y

    # Gradient Decent algo.
    def fit(self,x,y):
        self.raw_x=x
        x = np.array(self.raw_x, dtype=float)
        y = np.array(y, dtype=float).reshape(-1, 1)
     
        # Feature scaling 
        self.x_mean = x.mean(axis=0)
        self.x_std = x.std(axis=0) 
        x = (x - self.x_mean) / self.x_std
     
        m, n = x.shape
     
        # Add bias column
        ones = np.ones((m, 1))
        x = np.hstack((x, ones))  # (m, n+1)
     
        self.x = x
        self.y = y
     
        # Initialize weights
        self.a = np.zeros((n+1, 1))
     
        self.iteration = 0

        print('Print loss function after 100 iteration')
        
        while 1:      
           pre_loss=self.loss(x,y)
           
           self.d_w=0
           self.d_w = (-1/m)*( (x.T)@(y - x@self.a) )  # derivative of loss (n+1,1 )
            
           #define new weights
           self.a -= self.lr*(self.d_w)

           curr_loss=self.loss(x,y)
            
            # condition when gradient decent should stop
           if  abs(pre_loss - curr_loss) < 1e-6 or self.iteration >= self.max_iteration:
               break
           #increse no. of iteration each time by 1       
           self.iteration+=1
           if self.iteration % 100 == 0:
               print(" MSE loss = ",curr_loss)
    
    # calculating R^2 
    # R^2 = (SS(mean) - SS(predicted value)) / (SS(mean))  --> SS()=sum of square residue around  
    def r_square(self):
        y_predicted = self.predict(self.raw_x)

        y_mean = np.repeat(np.mean(self.y), len(self.y))  #np.repeat(number_to_repeat, n_times)
        y_mean=y_mean[:,None]
        SS_mean=sum( (y_mean -self.y)**2 )
        SS_predicted_value = sum( (y_predicted - self.y)**2 )

        return ((SS_mean - SS_predicted_value)/(SS_mean))[0]

    def predict(self, x):
        
       x = np.array(x, dtype=float)
       x = (x - self.x_mean) / self.x_std
    
       m = x.shape[0]
       ones = np.ones((m, 1))
       x = np.hstack((x, ones))
    
       return x @ self.a

# %% [markdown]
# #### __housing__ is our original data and all changes are done in __df__

# %%
# remove two column and  not change in original data insted make new 'df'
df = housing.drop(['longitude','latitude'],axis=1,inplace=False) 

# our dataset have 20,640 data points so we remove whole row with null value in 'total_bedrooms' column.
# change in df 
df.dropna(inplace=True)

df
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    41.0        880.0           129.0       322.0
# 1                    21.0       7099.0          1106.0      2401.0
# 2                    52.0       1467.0           190.0       496.0
# 3                    52.0       1274.0           235.0       558.0
# 4                    52.0       1627.0           280.0       565.0
# ...                   ...          ...             ...         ...
# 20635                25.0       1665.0           374.0       845.0
# 20636                18.0        697.0           150.0       356.0
# 20637                17.0       2254.0           485.0      1007.0
# 20638                18.0       1860.0           409.0       741.0
# 20639                16.0       2785.0           616.0      1387.0
#
#        households  median_income  median_house_value ocean_proximity
# 0           126.0         8.3252            452600.0        NEAR BAY
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   housing_median_age  20433 non-null  float64
#  1   total_rooms         20433 non-null  float64
#  2   total_bedrooms      20433 non-null  float64
#  3   population          20433 non-null  float64
#  4   households          20433 non-null  float64
#  5   median_income       20433 non-null  float64
#  6   median_house_value  20433 non-null  float64
#  7   ocean_proximity     20433 non-null  object
# dtypes: float64(7), object(1)
# memory usage: 1.4+ MB

# %% [markdown]
# #### converrt __ocean proximity__ data into numbers using __one hot label encoding__

# %%
df['ocean_proximity'].value_counts()
# 4 different types in ocena proximity
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns=['ocean_proximity'], drop_first=True,dtype=int)  # doing one hot encoding

# %%
df;

# %%
# also remove median_house_value from features and tag it as target(y)
x = df.drop(['median_house_value'],axis=1)
y = df['median_house_value']
x
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    41.0        880.0           129.0       322.0
# 1                    21.0       7099.0          1106.0      2401.0
# 2                    52.0       1467.0           190.0       496.0
# 3                    52.0       1274.0           235.0       558.0
# 4                    52.0       1627.0           280.0       565.0
# ...                   ...          ...             ...         ...
# 20635                25.0       1665.0           374.0       845.0
# 20636                18.0        697.0           150.0       356.0
# 20637                17.0       2254.0           485.0      1007.0
# 20638                18.0       1860.0           409.0       741.0
# 20639                16.0       2785.0           616.0      1387.0
#
#        households  median_income  ocean_proximity_INLAND  \
# 0           126.0         8.3252                       0
# ...

# %%
# split in test and train dataset

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
X_train;

# %% [markdown]
# ####  build multiple regression model

# %%
reg = multi_linear_reg(0.01,2000)
reg.fit(X_train, y_train)
# Final RMSE=sqrt(246,29,23,975) = 49,627
# Out:
# learning rate(lr)= 0.01
# maximum iteration= 2000
# Print loss function after 100 iteration
#  MSE loss =  5853057742.241512
#  MSE loss =  3024483480.557347
#  MSE loss =  2626690742.221067
#  MSE loss =  2554113443.7307067
#  MSE loss =  2529953989.863677
#  MSE loss =  2515692437.9020305
#  MSE loss =  2505166885.4641666
#  MSE loss =  2496922475.381573
#  MSE loss =  2490335008.6261764
#  MSE loss =  2485011181.428245
#  MSE loss =  2480668320.026381
#  MSE loss =  2477095106.8343606
#  MSE loss =  2474131154.7096243
#  MSE loss =  2471653643.1590567
#  MSE loss =  2469567827.4660316
#  MSE loss =  2467800098.259208
#  MSE loss =  2466292844.665253
#  MSE loss =  2465000628.8944006
#  MSE loss =  2463887325.706232
#  MSE loss =  2462923975.8041086

# %%
reg.r_square()
# Out:
# np.float64(0.6302346032508016)

# %%
reg.predict(X_train);

# %%
# coefficients- intercept matrix
reg.a
# lass one is bias( intercept ) 
# intercept = 207283
# Out:
# array([[ 15305.76956705],
#        [ -4510.80624724],
#        [ 25832.8511278 ],
#        [-37915.13501763],
#        [ 22293.92204547],
#        [ 74054.80991298],
#        [-33107.26796317],
#        [  2506.29148606],
#        [   751.58286875],
#        [  3947.50386829],
#        [207283.97997131]])

# %% [markdown]
# #### use same code but change loss function from MSE to MAE

# %%
class multi_linear_reg_MAE:
    def __init__(self,learning_rate=0.01,max_iteration=1000):
        self.lr=learning_rate 
        self.a=None # weight
        # take n+1 perameter into weigth last 1 is for bias
        
        self.max_iteration=max_iteration
        print('learning rate(lr)=',self.lr,'\nmaximum iteration=', self.max_iteration)
     
    def loss(self,x,y):
        # assume initial line as y=[0]*x + [0]
        loss_fun= np.abs( ( y - x@self.a ) )
        return np.sum(loss_fun)/(len(y))  # no of data points is same as len of y

    # Gradient Decent algo.
    def fit(self,x,y):
        self.raw_x=x
        x = np.array(self.raw_x, dtype=float)
        y = np.array(y, dtype=float).reshape(-1, 1)
     
        # Feature scaling 
        self.x_mean = x.mean(axis=0)
        self.x_std = x.std(axis=0) 
        x = (x - self.x_mean) / self.x_std
     
        m, n = x.shape
     
        # Add bias column
        ones = np.ones((m, 1))
        x = np.hstack((x, ones))  # (m, n+1)
     
        self.x = x
        self.y = y
     
        # Initialize weights
        self.a = np.zeros((n+1, 1))
     
        self.iteration = 0

        print('Print loss function after 100 iteration')
        
        while 1:      
           pre_loss=self.loss(x,y)
           
           self.d_w=0
           self.d_w = (-1/m)*( (x.T)@(y - x@self.a) )  # derivative of loss (n+1,1 )
            
           #define new weights
           self.a -= self.lr*(self.d_w)

           curr_loss=self.loss(x,y)
            
            # condition when gradient decent should stop
           if  abs(pre_loss - curr_loss) < 1e-6 or self.iteration >= self.max_iteration:
               break
           #increse no. of iteration each time by 1       
           self.iteration+=1
           if self.iteration % 100 == 0:
               print(" MAE loss = ",curr_loss)
    
    # calculating R^2 
    # R^2 = (SS(mean) - SS(predicted value)) / (SS(mean))  --> SS()=sum of square residue around  
    def r_square(self):
        y_predicted = self.predict(self.raw_x)

        y_mean = np.repeat(np.mean(self.y), len(self.y))  #np.repeat(number_to_repeat, n_times)
        y_mean=y_mean[:,None]
        SS_mean=sum( (y_mean -self.y)**2 )
        SS_predicted_value = sum( (y_predicted - self.y)**2 )

        return ((SS_mean - SS_predicted_value)/(SS_mean))[0]

    def predict(self, x):
        
       x = np.array(x, dtype=float)
       x = (x - self.x_mean) / self.x_std
    
       m = x.shape[0]
       ones = np.ones((m, 1))
       x = np.hstack((x, ones))
    
       return x @ self.a

# %%
reg_2=multi_linear_reg_MAE(0.01,2000)
# Out:
# learning rate(lr)= 0.01
# maximum iteration= 2000

# %%
reg_2.fit(X_train, y_train)
# Out:
# Print loss function after 100 iteration
#  MAE loss =  80144.03599616217
#  MAE loss =  53120.054170881805
#  MAE loss =  50978.002098592704
#  MAE loss =  51220.766508139684
#  MAE loss =  51358.677978034524
#  MAE loss =  51350.00939863941
#  MAE loss =  51280.18571521912
#  MAE loss =  51196.60275388753
#  MAE loss =  51117.40139100403
#  MAE loss =  51046.5546574715
#  MAE loss =  50985.498311243384
#  MAE loss =  50933.18885837311
#  MAE loss =  50888.16152648463
#  MAE loss =  50849.475962089564
#  MAE loss =  50816.437088421604
#  MAE loss =  50788.01312470171
#  MAE loss =  50763.732672387065
#  MAE loss =  50742.23376916672
#  MAE loss =  50723.3623081523
#  MAE loss =  50707.017891687035

# %%
reg_2.r_square()
# Out:
# np.float64(0.6302346032508016)

# %%
# coefficients - intercept matrix
reg_2.a
# Out:
# array([[ 15305.76956705],
#        [ -4510.80624724],
#        [ 25832.8511278 ],
#        [-37915.13501763],
#        [ 22293.92204547],
#        [ 74054.80991298],
#        [-33107.26796317],
#        [  2506.29148606],
#        [   751.58286875],
#        [  3947.50386829],
#        [207283.97997131]])

# %% [markdown]
# #### we can see that final value of  sqrt(MSE) = 49.7K and MAE = 50.7K which is nearly same

# %% [markdown]
# ####

# %% [markdown]
# ### *__Is high R2 score always good?__*

# %% [markdown]
# #### A higher R² value is not always better. In multiple linear regression, adding more independent variables will always increase (or at least not decrease) R², regardless of whether the new features are truly relevant or completely independent of the target. Even irrelevant features can randomly explain a small portion of the variance, causing R² to increase.
# #### To address this issue, Adjusted R² is used. Adjusted R² penalizes the model for adding unnecessary features and takes into account the number of predictors, increasing only when a new feature genuinely improves the model.

# %% [markdown]
# #####

# %% [markdown]
# ### *__Is low training loss always preferred?__*

# %% [markdown]
# #### No
# #### __Memorization (Overfitting):__ If the loss is too low, the model might just be memorizing the training data. It’s like a student who memorizes the exact answers to a practice test but fails the real exam because they don't actually understand the subject.
# #### __The Size of the Numbers:__ If we are predicting house prices, the numbers are huge. If a house costs \\$1,000,000 and our model predicts      \\$1,010,000 ,our error is only 1%. Even though the model is very accurate, the "Loss" (the math difference) will look like a huge, scary number (\\$10,000). High loss doesn't always mean a bad model; it just means we are dealing with big targets

# %% [markdown]
# ####

# %% [markdown]
# #### Plot:Predicted vs Actual

# %%
y_pred=reg.predict(X_test)
y_pred
# Out:
# array([[205175.30640749],
#        [139473.87124635],
#        [210763.15495643],
#        ...,
#        [151218.76874577],
#        [113328.92986058],
#        [101870.22663492]], shape=(6130, 1))

# %%
y_actual=y_test
y_actual
# Out:
# 14416    245800.0
# 16383    137900.0
# 7731     218200.0
# 1410     220800.0
# 1335     170500.0
#            ...
# 16764    287700.0
# 5762     241900.0
# 12862     88400.0
# 18814     77500.0
# 12852     72900.0
# Name: median_house_value, Length: 6130, dtype: float64

# %%
plt.scatter( y_pred/1000,y_actual/1000, color='#ADD8E6')
plt.ylabel('Y actual( in $1k)', color='#8B0000')
plt.xlabel('Y predicted( in $1k)',  color='#8B0000')
plt.title('y predicted vs y actual', color='#8B0000')
plt.plot([min(y_actual/1000), max(y_actual/1000)], [min(y_actual/1000), max(y_actual/1000)], color='red', label='Perfect Prediction (y=x)')

# Add text on line
#plt.text(x=250, y=280, s='y_actual=y_pred', rotation=50, ha='center', va='center',fontsize=12,color='red')
#plt.colorbar()

# %% [markdown]
# #####

# %% [markdown]
# #### Plot : Residuals vs Predicted

# %%
Y=y_actual.to_numpy() # convert series to numpy array
Y_actual = Y[:,None]  # convert to 2D arra (6130, ) to (6130,1)

# %%
y_residuals= Y_actual - y_pred 
y_residuals
# Out:
# array([[ 40624.69359251],
#        [ -1573.87124635],
#        [  7436.84504357],
#        ...,
#        [-62818.76874577],
#        [-35828.92986058],
#        [-28970.22663492]], shape=(6130, 1))

# %%
plt.scatter(y_residuals/1000, y_pred/1000, color='#ADD8E6')
plt.ylabel('(Predicted Values (in $1k)', color='#8B0000')
plt.xlabel('Residuals = Actual - Predicted ( in $1k)',  color='#8B0000')
plt.title('y predicted vs y actual', color='#8B0000')
# Out:
# Text(0.5, 1.0, 'y predicted vs y actual')

# %% [markdown]
# #### Most predictions have error within $\pm\$100k$ and centered around 0. Errors exceeding this range are likely driven by outliers that the current model cannot fully account for.
